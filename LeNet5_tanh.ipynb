# %%
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import MaxPooling2D, Conv2D, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Load dataset
(X_train,y_train),(X_test,y_test) = fashion_mnist.load_data()

# Dataset to categorical
class_count = 10
y_train_cat = to_categorical(y_train, num_classes=class_count)
y_test_cat = to_categorical(y_test, num_classes=class_count)

# Normalise data
X_train_norm = X_train / 255
X_test_norm = X_test / 255

# Reshape data
X_train_norm = X_train_norm.reshape(X_train_norm.shape[0], 28, 28, 1)
X_test_norm = X_test_norm.reshape(X_test_norm.shape[0], 28, 28, 1)


def leNet5(num_classes):
    model = Sequential()
    # Layer C1
    model.add(Conv2D(filters=6,
                     kernel_size=(5,5),
                     activation='tanh',
                     input_shape=(28,28,1)))
    # Layer S2
    model.add(MaxPooling2D(pool_size=(2,2)))
    # Layer C3
    model.add(Conv2D(filters=16,
                     kernel_size=(5,5),
                     activation='tanh'))
    # Layer S4
    model.add(MaxPooling2D(pool_size=(2,2)))
    # Flatten units
    model.add(Flatten())
    # Layer C5
    model.add(Dense(units=120,
                    activation='tanh'))
    # Layer F6
    model.add(Dense(units=84,
                    activation='tanh'))
    # Output layer
    model.add(Dense(units=num_classes,
                    activation='softmax'))
    return model

# Compile model
model = leNet5(class_count)

# To adjust the Learning Rate (lr), uncomment code below.
# from keras.optimizers import Adam
# opt = Adam(lr=0.001)
# model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define callback
callback = [EarlyStopping(monitor='val_loss', patience=10)]

# Fit the model
model.fit(x=X_train_norm, y=y_train_cat, validation_data=(X_test_norm,y_test_cat), epochs=100, batch_size=2048, callbacks=callback)

# Save model
model.save("leNet5_model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 27s 821ms/step - accuracy: 0.4511 - loss: 1.7667 - val_accuracy: 0.7235 - val_loss: 0.7724
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 709ms/step - accuracy: 0.7428 - loss: 0.6994 - val_accuracy: 0.7699 - val_loss: 0.6148
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 782ms/step - accuracy: 0.7875 - loss: 0.5775 - val_accuracy: 0.7916 - val_loss: 0.5554
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 757ms/step - accuracy: 0.8092 - loss: 0.5246 - val_accuracy: 0.8162 - val_loss: 0.5108
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 721ms/step - accuracy: 0.8268 - loss: 0.4793 - val_accuracy: 0.8262 - val_loss: 0.4778
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 746ms/step - accuracy: 0.8372 - loss: 0.4503 - val_accuracy: 0.8356 - val_loss: 0.4564
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 719ms/step - accuracy: 0.8479 - loss: 0.4227 - val_accuracy: 0.8447 - val_loss: 0.4309
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 717ms/step - accuracy: 0.8527 - loss: 0.4055 - val_accuracy: 0.8516 - val_loss: 0.4165
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 43s 782ms/step - accuracy: 0.8606 - loss: 0.3892 - val_accuracy: 0.8457 - val_loss: 0.4198
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 715ms/step - accuracy: 0.8629 - loss: 0.3786 - val_accuracy: 0.8601 - val_loss: 0.3919
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 752ms/step - accuracy: 0.8703 - loss: 0.3592 - val_accuracy: 0.8540 - val_loss: 0.4023
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━
# Epoch 64/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 776ms/step - accuracy: 0.9302 - loss: 0.1960 - val_accuracy: 0.8952 - val_loss: 0.2981
# Epoch 65/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 772ms/step - accuracy: 0.9306 - loss: 0.1948 - val_accuracy: 0.8958 - val_loss: 0.2967
# Epoch 66/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 24s 815ms/step - accuracy: 0.9290 - loss: 0.1927 - val_accuracy: 0.8970 - val_loss: 0.2929
# Epoch 67/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 748ms/step - accuracy: 0.9308 - loss: 0.1892 - val_accuracy: 0.8958 - val_loss: 0.2948
# Epoch 68/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 795ms/step - accuracy: 0.9306 - loss: 0.1929 - val_accuracy: 0.8989 - val_loss: 0.2943
# Epoch 69/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 723ms/step - accuracy: 0.9284 - loss: 0.1919 - val_accuracy: 0.8939 - val_loss: 0.3024
# Epoch 70/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 43s 789ms/step - accuracy: 0.9294 - loss: 0.1905 - val_accuracy: 0.8986 - val_loss: 0.2924
# Epoch 71/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 764ms/step - accuracy: 0.9308 - loss: 0.1884 - val_accuracy: 0.8946 - val_loss: 0.3038
# Epoch 72/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 42s 797ms/step - accuracy: 0.9295 - loss: 0.1906 - val_accuracy: 0.8986 - val_loss: 0.2912
# Epoch 73/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 720ms/step - accuracy: 0.9352 - loss: 0.1796 - val_accuracy: 0.8963 - val_loss: 0.3022
# Epoch 74/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 730ms/step - accuracy: 0.9335 - loss: 0.1815 - val_accuracy: 0.8996 - val_loss: 0.2907
# Epoch 75/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 720ms/step - accuracy: 0.9365 - loss: 0.1776 - val_accuracy: 0.8964 - val_loss: 0.2959
# Epoch 76/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 43s 781ms/step - accuracy: 0.9355 - loss: 0.1768 - val_accuracy: 0.8935 - val_loss: 0.3019
# Epoch 77/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 773ms/step - accuracy: 0.9336 - loss: 0.1819 - val_accuracy: 0.8974 - val_loss: 0.2999
# Epoch 78/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 21s 698ms/step - accuracy: 0.9353 - loss: 0.1768 - val_accuracy: 0.8961 - val_loss: 0.3002
# Epoch 79/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 771ms/step - accuracy: 0.9360 - loss: 0.1751 - val_accuracy: 0.8971 - val_loss: 0.2970
# Epoch 80/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 778ms/step - accuracy: 0.9365 - loss: 0.1746 - val_accuracy: 0.8961 - val_loss: 0.3016
# Epoch 81/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 754ms/step - accuracy: 0.9359 - loss: 0.1754 - val_accuracy: 0.8989 - val_loss: 0.2943
# Epoch 82/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 41s 742ms/step - accuracy: 0.9394 - loss: 0.1668 - val_accuracy: 0.8987 - val_loss: 0.2965
# Epoch 83/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 772ms/step - accuracy: 0.9395 - loss: 0.1663 - val_accuracy: 0.8960 - val_loss: 0.2988
# Epoch 84/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 22s 720ms/step - accuracy: 0.9367 - loss: 0.1727 - val_accuracy: 0.8979 - val_loss: 0.2967
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from sklearn.metrics import accuracy_score

batch_size = 1024
y_pred_train = to_categorical(model.predict(X_train_norm,batch_size=batch_size).argmax(axis=1), num_classes=10)
y_pred_test = to_categorical(model.predict(X_test_norm,batch_size=batch_size).argmax(axis=1), num_classes=10)

print('Training Accuracy:', accuracy_score(y_pred_train, y_train_cat))
print('Testing Accuracy:', accuracy_score(y_pred_test, y_test_cat))
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step
# Training Accuracy: 0.94155
# Testing Accuracy: 0.8979
